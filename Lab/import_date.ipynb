# %% [markdown]
# # Import Date Python file

# %%
# import python file
from python_14_11_4 import *

# %%
# create first instance of class 
first_date = Date(1933, 6, 22)

# create second instance of class 
second_date = Date(1933, 9, 17)

# %%
# print dates 
first_date.print_date()
second_date.print_date()
# Out:
# 1933-06-22
# 1933-09-17

# %%
# Does the first date come after the second date
first_date.is_after(second_date)
# Out:
# False

# %%
# Third date test
third_date = Date(1933, 10, 31)
third_date.print_date()
third_date.is_after(second_date)
# Out:
# 1933-10-31
# True
